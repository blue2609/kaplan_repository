# %%
import pandas as pd

# %%
df = pd.read_csv('./application/AllAppsList.csv')

# %%
for application in df.itertuples():
    print(application.InstallLocation)
# Out:
# C:\Users\stanley.setiawan\AppData\Local\TIBCO\Spotfire Cloud\11.2.0\
# nan
# nan
# nan
# nan
# nan
# C:\Program Files (x86)\Citrix\ICA Client\
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# C:\Program Files\Intel
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# C:\Program Files\Tableau\Tableau 2020.2
# nan
# nan
# nan
# nan
# nan
# nan
# C:\Program Files (x86)\Java\jre1.8.0_171\
# C:\Program Files\Java\jre1.8.0_171\
# nan
# nan
# C:\Program Files\Sophos\Endpoint Self Help\
# nan
# nan
# C:\Program Files\Tableau\Tableau 2021.1
# nan
# nan
# nan
# nan
# nan
# nan
# C:\Program Files (x86)\Common Files\Adobe\ARM\1.0\
# C:\Program Files (x86)\Adobe\Acrobat Reader DC\
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# C:\Program Files (x86)\Sophos\Sophos Anti-Virus\
# C:\Program Files\DisplayLink Core Software\
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# C:\Program Files (x86)\Sophos\Sophos Diagnostic Utility\
# nan
# nan
# nan
# nan
# ...

# %%
df
# Out:
#                                                  Name         Version  \
# 0                 TIBCO Cloud Spotfire Analyst 11.2.0          11.2.0
# 1      Office 16 Click-to-Run Extensibility Component  16.0.9226.2114
# 2       Office 16 Click-to-Run Localization Component  16.0.9226.2114
# 3   Office 16 Click-to-Run Extensibility Component...  16.0.9226.2114
# 4          Office 16 Click-to-Run Licensing Component  16.0.9226.2114
# ..                                                ...             ...
# 89  SQL Server Management Studio for Analysis Serv...    15.0.18369.0
# 90                          Microsoft Policy Platform     68.1.1010.0
# 91                    SQL Server 2017 Connection Info   14.0.1000.169
# 92              Microsoft SQL Server 2017 RsFx Driver   14.0.1000.169
# 93                                SQL Server 2017 DMF   14.0.1000.169
#
#                                       InstallLocation InstallDate
# ...

# %%
pd.concat([pd.DataFrame([[1,2],[3,4]]),
          pd.DataFrame([[5,6],[7,8]])])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-45d23af9c774> in <module>
# ----> 1 pd.concat([pd.DataFrame([[1,2],[3,4]]),
#       2           pd.DataFrame([[5,6],[7,8]])])
#
# NameError: name 'pd' is not defined

# %%
import requests

# %%
response = requests.get('https://downloads.tableau.com/esdalt/2020.3.8/TableauDesktop-64bit-2020-3-8.exe',allow_redirects=True)
open('TableauDesktop.exe','wb').write(response.content)
# Out:
# 498238432

# %%
import shlex
import subprocess 

packageID = 'Tableau-Desktop'
commandList = shlex.split(f'choco search {packageID} --all --local-only')
# commandList = shlex.split(f'choco search {packageID} --all --verbose')
process = subprocess.Popen(commandList,stdout=subprocess.PIPE)
output = process.communicate()[0]
print(output)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-f487226ff949> in <module>
#       5 commandList = shlex.split(f'choco search {packageID} --all --local-only')
#       6 # commandList = shlex.split(f'choco search {packageID} --all --verbose')
# ----> 7 process = subprocess.Popen(commandList,stout=subprocess.PIPE)
#       8 output = process.communicate()[0]
#       9 print(output)
#
# TypeError: __init__() got an unexpected keyword argument 'stout'
